# %% [markdown]
# # Download news articles per subject

# %% [markdown]
# This notebook guides you through the SRU and OAI of the KB: National Library of the Netherlands, in order to collect news articles based on subject and time range.

# %% [markdown]
# ### Install the neccesary packages
#
# It is preffered to install the package through a commandline, but installing through the Jupypter Notebook is also possible.

# %%
# !pip install pandas
# !pip install requests
# !pip install BeautifulSoup4
# !pip install lxml
# !pip install html5lib

# %% [markdown]
# ### Import  the neccesary packages

# %%
## Import the necessary packages 
import pandas as pd
from bs4 import BeautifulSoup
import requests
import xml

# %% [markdown]
# ### Defining the API key
#
# An API key is needed to query and download material.

# %%
apikey = "" #Insert the API key here

# %% [markdown]
# ### Defining the search parameters
#
# There are various parameters that can be used to search through the collection.
# The code in this notebook is based on searching with a keyword and a time range.
#
# Furthermore, other parameters can be searched, such as the type of content or the spatial. Reference the user manual for more information about the other parameters.

# %%
keyword = 'Inhuldiging+and+koningin+and+Beatrix' ## use '+or+' or '+and+' to search with multiple keywords, such as 'griep+and+ziekte'
startdate = '01-01-1980'
enddate = '31-12-1980'

# %% [markdown]
# ### Retrieving the newspaper issue identifiers
#
# Before we can download the actual content, we need a list of identifiers from the news articles that fit to the selection criteria we made above. We put this list in a dataframe in which we store some additional metadata  about the newspaper. This  dataframe is used later on for accessing the content.

# %%
## Extract the identifiers
## This might take a while
identifierList = []
startRecord = 0
recordCounter = 0

## Assemble the query based on the parameters, we set the  maximumRecords to 1000 to prevent overloading the system
query = f"https://jsru.kb.nl/sru/sru/{apikey}?query={keyword}"\
        f"%20and%20(date%20within%20%22{startdate}%20{enddate}%22)"\
        f"&x-collection=DDD_artikel&recordSchema=dc&startRecord={startRecord}&maximumRecords=1000"

print(query)


page = requests.get(query)
soup = BeautifulSoup(page.content,'xml')
print(soup)

for item in soup.findAll('srw:searchRetrieveResponse'):
    records = item.find('srw:numberOfRecords').text
    
## Iterate through the query results to extract the metadata 
while recordCounter < int(records):
    page = requests.get(query)
    soup = BeautifulSoup(page.content, 'xml')

    ## The query returns an xml page with (in this example) 1000 articles 
    ## We extract the metadate per article
    for item in soup.findAll('srw:recordData'):
        identifier = item.find('dc:identifier')
        kind =  item.find('dc:type')    
        title = item.find('dc:title')
        papertitle = item.find('dc:publisher')
        date = item.find('dc:date')
        if title is None:
            title = ""    
            identifierList.append([identifier.text, kind.text, title, date.text])
        else:
            identifierList.append([identifier.text, kind.text, title.text, date.text])
        recordCounter += 1
    ## If there are more than 1000 results, 
    ## this code is used to proceed to the next pages to collect the remainder of the results
    startRecord = startRecord + 1000
    query = f"https://jsru.kb.nl/sru/sru/{apikey}?query={keyword}"\
        f"%20and%20(date%20within%20%22{startdate}%20{enddate}%22)"\
        f"&x-collection=DDD_artikel&recordSchema=dc&startRecord={startRecord}&maximumRecords=1000"
# Out:
# https://jsru.kb.nl/sru/sru/31147d97-a7e2-47a5-8fa8-ca72bfd8ce15?query=Inhuldiging+and+koningin+and+Beatrix%20and%20(date%20within%20%2201-01-1980%2031-12-1980%22)&x-collection=DDD_artikel&recordSchema=dc&startRecord=0&maximumRecords=1000
# <?xml version="1.0" encoding="utf-8"?>
# <srw:searchRetrieveResponse xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcx="http://krait.kb.nl/coop/tel/handbook/telterms.html" xmlns:diag="http://www.loc.gov/zing/srw/diagnostic/" xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:tel="http://krait.kb.nl/coop/tel/handbook/telterms.html" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><srw:version>1.1</srw:version><srw:totalMilliSeconds>3592</srw:totalMilliSeconds><srw:searchEngineMilliSeconds>3567</srw:searchEngineMilliSeconds><srw:kbmdoMilliSeconds>-1</srw:kbmdoMilliSeconds><srw:numberOfRecords>1089</srw:numberOfRecords><srw:records><srw:record><srw:recordPacking>xml</srw:recordPacking><srw:recordSchema>info:srw/schema/1/dc-v1.1</srw:recordSchema><srw:recordData><dc:identifier>http://resolver.kb.nl/resolve?urn=ddd:011200702:mpeg21:a0139:ocr</dc:identifier><dc:rights>Uitgeversmaatschappij De Telegraaf B.V.</dc:rights><dc:date>1980/02/18 00:00:00</dc:date><dc:publisher>Dagblad De Telegraaf</dc:publisher><OaiPmhIdentifier>DDD:ddd:011200702:mpeg21</OaiPmhIdentifier><dc:source>Koninklijke Bibliotheek C 89</dc:source><dcx:DelpherPublicationDate>Wed Nov 20 01:00:00 CET 2013</dcx:DelpherPublicationDate><dcx:issued>1893</dcx:issued><dc:title>Inhuldiging Beatrix op de plaat</dc:title><dc:type>artikel</dc:type></srw:recordData><srw:recordPosition>1</srw:recordPosition></srw:record><srw:record><srw:recordPacking>xml</srw:recordPacking><srw:recordSchema>info:srw/schema/1/dc-v1.1</srw:recordSchema><srw:recordData><dc:identifier>http://resolver.kb.nl/resolve?urn=ddd:010573169:mpeg21:a0059:ocr</dc:identifier><dc:rights>Nederlands Dagblad B.V.</dc:rights><dc:date>1980/08/15 00:00:00</dc:date><dc:publisher>Stichting Nederlands Dagblad</dc:publisher><OaiPmhIdentifier>DDD:ddd:010573169:mpeg21</OaiPmhIdentifier><dc:source>Nederlands Dagblad</dc:source><dcx:DelpherPublicationDate>Wed Nov 20 01:00:00 CET 2013</dcx:DelpherPublicationDate><dcx:issued>1967</dcx:issued><dc:title>Inhuldiging koningin Beatrix trok meeste kijkers in 2e kwartaal</dc:title><dc:type>artikel</dc:type></srw:recordData><srw:recordPosition>2</srw:recordPosition></srw:record><srw:record><srw:recordPacking>xml</srw:recordPacking><srw:recordSchema>info:srw/schema/1/dc-v1.1</srw:recordSchema><srw:recordData><dc:identifier>http://resolver.kb.nl/resolve?urn=ddd:010376929:mpeg21:a0111:ocr</dc:identifier><dc:rights>De Stichting tot beheer van de archieven van de CPN</dc:rights><dc:date>1980/02/11 00:00:00</dc:date><dc:publisher>s.n.</dc:publisher><OaiPmhIdentifier>DDD:ddd:010376929:mpeg21</OaiPmhIdentifier><dc:source>KB C 157</dc:source><dcx:DelpherPublicationDate>Wed Nov 20 01:00:00 CET 2013</dcx:DelpherPublicationDate><dcx:issued>1940-1990</dcx:issued><dc:title>Troonsafstand en inhuldiging op één dag</dc:title><dc:type>artikel</dc:type></srw:recordData><srw:recordPosition>3</srw:recordPosition></srw:record><srw:record><srw:recordPacking>xml</srw:recordPacking><srw:recordSchema>info:srw/schema/1/dc-v1.1</srw:recordSchema><srw:recordData><dc:identifier>http://resolver.kb.nl/resolve?urn=KBPERS01:002963005:mpeg21:a00017:ocr</dc:identifier><dcx:projectcode>BKT-KRANTEN5</dcx:projectcode><dc:date>1980/03/07 00:00:00</dc:date><OaiPmhIdentifier>KRANTEN:KBPERS01:KBPERS01:002963005:mpeg21</OaiPmhIdentifier><dc:source>Koninklijke Bibliotheek</dc:source><dc:title>Prins Charles bij inhuldiging</dc:title><dc:type>artikel</dc:type><dcx:DelpherPublicationDate>Mon Apr 20 02:00:00 CEST 2020</dcx:DelpherPublicationDate><dc:rights>Koninklijke Bibliotheek Den Haag</dc:rights><dc:publisher>Stichting Algemeen Dagblad</dc:publisher><dcx:issued>1946-2005</dcx:issued></srw:recordData><srw:recordPosition>4</srw:recordPosition></srw:record><srw:record><srw:recordPacking>xml</srw:recordPacking><srw:recordSchema>info:srw/schema/1/dc-v1.1</srw:recordSchema><srw:recordData><dc:identifier>http://resolver.kb.nl/resolve?urn=ddd:010570804:mpeg21:a0145:ocr</dc:identifier><dc:rights>Media Groep Limburg</dc:rights><dc:date>1980/04/30 00:00:00</dc:date><dc:publishe ...

# %%
## Create the dataframe
dfIdentifiers = pd.DataFrame(identifierList, columns = ['identifier', 'type', 'title', 'date'])
## Show the number of found identifiers
print('Found: ',len(dfIdentifiers))
csvlist = dfIdentifiers.to_csv('identifierslist.csvlist')
dfIdentifiers.head(40)
# Out:
# Found:  1090
#                                            identifier     type  \
# 0   http://resolver.kb.nl/resolve?urn=ddd:01120070...  artikel
# 1   http://resolver.kb.nl/resolve?urn=ddd:01057316...  artikel
# 2   http://resolver.kb.nl/resolve?urn=ddd:01037692...  artikel
# 3   http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 4   http://resolver.kb.nl/resolve?urn=ddd:01057080...  artikel
# 5   http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 6   http://resolver.kb.nl/resolve?urn=ddd:01120069...  artikel
# 7   http://resolver.kb.nl/resolve?urn=ddd:01120076...  artikel
# 8   http://resolver.kb.nl/resolve?urn=ABCDDD:01084...  artikel
# 9   http://resolver.kb.nl/resolve?urn=ddd:01120490...  artikel
# 10  http://resolver.kb.nl/resolve?urn=ddd:01062134...  artikel
# 11  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 12  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 13  http://resolver.kb.nl/resolve?urn=ddd:01062131...  artikel
# 14  http://resolver.kb.nl/resolve?urn=ddd:01062133...  artikel
# 15  http://resolver.kb.nl/resolve?urn=ddd:01062138...  artikel
# 16  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...  artikel
# 17  http://resolver.kb.nl/resolve?urn=ddd:01057058...  artikel
# 18  http://resolver.kb.nl/resolve?urn=ddd:01101896...  artikel
# 19  http://resolver.kb.nl/resolve?urn=ddd:01062139...  artikel
# 20  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...  artikel
# 21  http://resolver.kb.nl/resolve?urn=ddd:01062139...  artikel
# 22  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...  artikel
# 23  http://resolver.kb.nl/resolve?urn=ddd:01120490...  artikel
# 24  http://resolver.kb.nl/resolve?urn=ddd:01037692...  artikel
# 25  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 26  http://resolver.kb.nl/resolve?urn=KBPERS01:003...  artikel
# 27  http://resolver.kb.nl/resolve?urn=ddd:01120068...  artikel
# 28  http://resolver.kb.nl/resolve?urn=ddd:01120071...  artikel
# 29  http://resolver.kb.nl/resolve?urn=ddd:01062139...  artikel
# 30  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 31  http://resolver.kb.nl/resolve?urn=ddd:01057059...  artikel
# 32  http://resolver.kb.nl/resolve?urn=ddd:01101898...  artikel
# 33  http://resolver.kb.nl/resolve?urn=ddd:01096044...  artikel
# 34  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 35  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 36  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...  artikel
# 37  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 38  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...  artikel
# 39  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...  artikel
#
#                                                 title                 date
# 0                     Inhuldiging Beatrix op de plaat  1980/02/18 00:00:00
# 1   Inhuldiging koningin Beatrix trok meeste kijke...  1980/08/15 00:00:00
# 2             Troonsafstand en inhuldiging op één dag  1980/02/11 00:00:00
# 3                       Prins Charles bij inhuldiging  1980/03/07 00:00:00
# 4                                         NEDERLAND I  1980/04/30 00:00:00
# 5                                                  TV  1980/04/29 00:00:00
# 6   VROUW DE KLEREN VAN DE KONINGIN door Dieuwke G...  1980/02/09 00:00:00
# 7        Beatrix na inhuldiging beschermvrouwe Unicef  1980/03/31 00:00:00
# 8   Troonsafstand zal niet tot collectieve gratie ...  1980/02/09 00:00:00
# 9                                Inhuldiging Koningin  1980/08/07 00:00:00
# 10         Kroonprins Charles bij inhuldiging Beatrix  1980/03/07 00:00:00
# 11  Beatrix geeft Kamerleden opvallende plaats bij...  1980/03/07 00:00:00
# 12                Scheel naar inhuldiging van Beatrix  1980/04/15 00:00:00
# 13  Koninginnedag houdt dezelfde datum Inhuldiging...  1980/02/02 00:00:00
# 14                     PSP blijft weg bij inhuldiging  1980/02/21 00:00:00
# 15  Leden Europees Parlement dreigen weg te blijve...  1980/04/21 00:00:00
# 16  ORANJEVERENIGINGEN: 'Inhuldiging Beatrix lieve...  1980/02/11 00:00:00
# 17  Oranjeverenigingen: Inhuldiging Beatrix liever...  1980/02/11 00:00:00
# 18                 Inhuldiging Beatrix niet vervroegd  1980/02/29 00:00:00
# 19                      Tv-programma op Koninginnedag  1980/04/29 00:00:00
# 20              Prins Charles bij inhuldiging Beatrix  1980/03/07 00:00:00
# 21  Brandpunt in het teken van inhuldiging van Bea...  1980/04/29 00:00:00
# 22  Eerbetoon aan verzet bij inhuldiging DOOR PAUL...  1980/04/25 00:00:00
# 23                  Inhuldiging Beatrix meest bekeken  1980/08/15 00:00:00
# 24                    Inhuldiging Beatrix op 30 april  1980/02/04 00:00:00
# 25                                 SOBERE INHULDIGING  1980/02/09 00:00:00
# 26                               Ongedwongen koningin  1980/05/01 00:00:00
# 27          Op moment van afstand is Beatrix Koningin  1980/02/01 00:00:00
# 28                          Postzegel bij inhuldiging  1980/02/27 00:00:00
# 29       Eerste inhuldigings-lp voor koningin Beatrix  1980/05/07 00:00:00
# 30                Inhuldiging Beatrix zal sober zijn’  1980/02/14 00:00:00
# 31                           KRONING BEATRIX OM 3 UUR  1980/02/29 00:00:00
# 32                       Beatrix houdt Unicef-functie  1980/03/31 00:00:00
# 33               Inhuldiging van Beatrix om 14.30 uur  1980/03/01 00:00:00
# 34                    Inhuldiging Beatrix niet eerder  1980/02/28 00:00:00
# 35                Inhuldiging van Beatrix ’s morgens’  1980/02/11 00:00:00
# 36  Inhuldiging koningin Beatril trok de meeste ki...  1980/08/15 00:00:00
# 37                     Inhuldiging 'volgens traditie’  1980/03/01 00:00:00
# 38       Speciaal vandaag Programma's troonswisseling  1980/04/30 00:00:00
# 39                               Zetels voor de Kroon  1980/02/08 00:00:00

# %% [markdown]
# ### Retrieve the content of the articles

# %%
## Retreive the content of the articles based on the identifiers
## If there are a lot of articles, this can take a while

contentList = []

for index, row in dfIdentifiers.iterrows():
    identifier = row['identifier']
    url = requests.get(identifier)
    soup = BeautifulSoup(url.content, "xml")
    text = ''
    for item in soup.findAll('p'):
        text = text + (item.text)
    contentList.append([identifier, text])

# %%
## Create a dataframe
dfText = pd.DataFrame(contentList, columns = ['identifier', 'content'])

# %%
len(dfText)
# Out:
# 1090

# %%
dfText.head(4)
# Out:
#                                           identifier  \
# 0  http://resolver.kb.nl/resolve?urn=ddd:01120070...
# 1  http://resolver.kb.nl/resolve?urn=ddd:01057316...
# 2  http://resolver.kb.nl/resolve?urn=ddd:01037692...
# 3  http://resolver.kb.nl/resolve?urn=KBPERS01:002...
#
#                                              content
# 0  PHONOGRAM heeft de rechten van de NOS gekocht ...
# 1  HILVERSUM [ANP] - Met een kijkdichtheidspercen...
# 2  De troonsafstand van Juliana en de inhuldiging...
# 3  LONDEN (Reuter) Kroonprins Charles zal de Brit...

# %%
dfText[dfText['content'].str.contains('rel')]
# Out:
#                                              identifier  \
# 25    http://resolver.kb.nl/resolve?urn=KBPERS01:002...
# 26    http://resolver.kb.nl/resolve?urn=KBPERS01:003...
# 43    http://resolver.kb.nl/resolve?urn=ddd:01062141...
# 58    http://resolver.kb.nl/resolve?urn=ddd:01101904...
# 66    http://resolver.kb.nl/resolve?urn=ddd:01120078...
# ...                                                 ...
# 1084  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 1085  http://resolver.kb.nl/resolve?urn=ABCDDD:01088...
# 1087  http://resolver.kb.nl/resolve?urn=ddd:01057314...
# 1088  http://resolver.kb.nl/resolve?urn=ddd:01057309...
# 1089  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
#
#                                                 content
# 25    • WIELERKAMPIOENEN OP BEZOEK BIJ KONINGINSlaot...
# 26    Van een onzer verslaggevers AMSTERDAM - Onze n...
# 43    DEN HAAG - Koningin Beatrix zal in een toespra...
# 58    Koningin Beatrix zal op dinsdag 10 juni in een...
# 66    f Twee informatieve kleurenfolders van > Monum...
# ...                                                 ...
# 1084  r» ui gp„n, r- Als nst'me* de regelmaat van ee...
# 1085  Ll artkruis is bondscoach en militair. Hij sta...
# 1087  JTW??T^CTIfj_[3B^No. 1361: 'n boek hoort erbij...
# 1088  _TT?H?f!ff!ffl No. 1352 Nagelaten boodschap Di...
# 1089  Jifts Wiegel, minister van bin- Wandse zaken, ...
#
# [352 rows x 2 columns]

# %% [markdown]
# ### Merge the metadata with the content
#
# This is an additional step to store everything in one dataframe.

# %%
dfArticles = dfIdentifiers.merge(dfText, on = 'identifier', how = 'inner')

# %%
dfArticles.head(4)
# Out:
#                                           identifier     type  \
# 0  http://resolver.kb.nl/resolve?urn=ddd:01120070...  artikel
# 1  http://resolver.kb.nl/resolve?urn=ddd:01057316...  artikel
# 2  http://resolver.kb.nl/resolve?urn=ddd:01037692...  artikel
# 3  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
#
#                                                title                 date  \
# 0                    Inhuldiging Beatrix op de plaat  1980/02/18 00:00:00
# 1  Inhuldiging koningin Beatrix trok meeste kijke...  1980/08/15 00:00:00
# 2            Troonsafstand en inhuldiging op één dag  1980/02/11 00:00:00
# 3                      Prins Charles bij inhuldiging  1980/03/07 00:00:00
#
#                                              content
# 0  PHONOGRAM heeft de rechten van de NOS gekocht ...
# 1  HILVERSUM [ANP] - Met een kijkdichtheidspercen...
# 2  De troonsafstand van Juliana en de inhuldiging...
# 3  LONDEN (Reuter) Kroonprins Charles zal de Brit...

# %%
dfArticles[dfArticles['content'].str.contains('rel')]
# Out:
#                                              identifier         type  \
# 25    http://resolver.kb.nl/resolve?urn=KBPERS01:002...      artikel
# 26    http://resolver.kb.nl/resolve?urn=KBPERS01:003...      artikel
# 43    http://resolver.kb.nl/resolve?urn=ddd:01062141...      artikel
# 58    http://resolver.kb.nl/resolve?urn=ddd:01101904...      artikel
# 66    http://resolver.kb.nl/resolve?urn=ddd:01120078...  advertentie
# ...                                                 ...          ...
# 1086  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...      artikel
# 1087  http://resolver.kb.nl/resolve?urn=ABCDDD:01088...      artikel
# 1089  http://resolver.kb.nl/resolve?urn=ddd:01057314...  advertentie
# 1090  http://resolver.kb.nl/resolve?urn=ddd:01057309...  advertentie
# 1091  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...      artikel
#
#                                                   title                 date  \
# 25                                   SOBERE INHULDIGING  1980/02/09 00:00:00
# 26                                 Ongedwongen koningin  1980/05/01 00:00:00
# 43                   Danktoespraak van koningin Beatrix  1980/05/29 00:00:00
# 58                           Dankwoord koningin Beatrix  1980/05/30 00:00:00
# 66                                          Advertentie  1980/04/26 00:00:00
# ...                                                 ...                  ...
# 1086              AMOK, de homars van het nieuwe Pompeï  1980/05/10 00:00:00
# 1087  SPORT „Huidige generatie niet spontaan of zelf...  1980/06/07 00:00:00
# 1089                                        Advertentie  1980/07/19 00:00:00
# 1090                                        Advertentie  1980/05/17 00:00:00
# 1091  ‘Ik heb het nóg netjes gezegd’ Vlegel luchtte ...  1980/05/31 00:00:00
#
#                                                 content
# 25    • WIELERKAMPIOENEN OP BEZOEK BIJ KONINGINSlaot...
# 26    Van een onzer verslaggevers AMSTERDAM - Onze n...
# 43    DEN HAAG - Koningin Beatrix zal in een toespra...
# 58    Koningin Beatrix zal op dinsdag 10 juni in een...
# 66    f Twee informatieve kleurenfolders van > Monum...
# ...                                                 ...
# 1086  r» ui gp„n, r- Als nst'me* de regelmaat van ee...
# 1087  Ll artkruis is bondscoach en militair. Hij sta...
# 1089  JTW??T^CTIfj_[3B^No. 1361: 'n boek hoort erbij...
# 1090  _TT?H?f!ff!ffl No. 1352 Nagelaten boodschap Di...
# 1091  Jifts Wiegel, minister van bin- Wandse zaken, ...
#
# [354 rows x 5 columns]

# %%
# dfArticles = dfArticles.head(10)
print(dfArticles.head(10))

csvdfArticles = dfArticles.to_html('Articles.html')
# Out:
#                                           identifier     type  \
# 0  http://resolver.kb.nl/resolve?urn=ddd:01120070...  artikel
# 1  http://resolver.kb.nl/resolve?urn=ddd:01057316...  artikel
# 2  http://resolver.kb.nl/resolve?urn=ddd:01037692...  artikel
# 3  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 4  http://resolver.kb.nl/resolve?urn=ddd:01057080...  artikel
# 5  http://resolver.kb.nl/resolve?urn=KBPERS01:002...  artikel
# 6  http://resolver.kb.nl/resolve?urn=ddd:01120069...  artikel
# 7  http://resolver.kb.nl/resolve?urn=ddd:01120076...  artikel
# 8  http://resolver.kb.nl/resolve?urn=ABCDDD:01084...  artikel
# 9  http://resolver.kb.nl/resolve?urn=ddd:01120490...  artikel
#
#                                                title                 date  \
# 0                    Inhuldiging Beatrix op de plaat  1980/02/18 00:00:00
# 1  Inhuldiging koningin Beatrix trok meeste kijke...  1980/08/15 00:00:00
# 2            Troonsafstand en inhuldiging op één dag  1980/02/11 00:00:00
# 3                      Prins Charles bij inhuldiging  1980/03/07 00:00:00
# 4                                        NEDERLAND I  1980/04/30 00:00:00
# 5                                                 TV  1980/04/29 00:00:00
# 6  VROUW DE KLEREN VAN DE KONINGIN door Dieuwke G...  1980/02/09 00:00:00
# 7       Beatrix na inhuldiging beschermvrouwe Unicef  1980/03/31 00:00:00
# 8  Troonsafstand zal niet tot collectieve gratie ...  1980/02/09 00:00:00
# 9                               Inhuldiging Koningin  1980/08/07 00:00:00
#
#                                              content
# 0  PHONOGRAM heeft de rechten van de NOS gekocht ...
# 1  HILVERSUM [ANP] - Met een kijkdichtheidspercen...
# 2  De troonsafstand van Juliana en de inhuldiging...
# 3  LONDEN (Reuter) Kroonprins Charles zal de Brit...
# 4  Kanalen: 5, 51, 53 en 579.45 - ca. 11.30 Troon...
# 5  en opVan onze radio en tv-redactie HILVERSUM -...
# 6  AMSTERDAM, zaterdag Wat zal prinses Beatrix dr...
# 7  UTRECHT, maandag Prinses Beatrix, die nu nog e...
# 8  (Van onze Haagse redactie) DEN HAAG — Bij de t...
# 9  Van onze parlementaire redactie 1 DEN HAAG, do...
